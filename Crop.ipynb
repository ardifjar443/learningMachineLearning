# %%
import pandas as pd
# Out:
# /var/folders/1q/ttq7y9792hl1j72br9_w4vzw0000gn/T/ipykernel_8906/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("./dataset/Database.csv")

# %%
display(df)
# Out:
#             Author                   Journal  Year Site country  \
# 0     Aase  et al.  Soil & Tillage Research   1997          USA
# 1     Aase  et al.  Soil & Tillage Research   1997          USA
# 2     Aase  et al.  Soil & Tillage Research   1997          USA
# 3          Acharya   Soil & Tillage Research  2019          USA
# 4          Acharya   Soil & Tillage Research  2019          USA
# ...            ...                       ...   ...          ...
# 4398         Zugec   Soil & Tillage Research  1986      Croatia
# 4399         Zugec   Soil & Tillage Research  1986      Croatia
# 4400         Zugec   Soil & Tillage Research  1986      Croatia
# 4401         Zugec   Soil & Tillage Research  1986      Croatia
# 4402         Zugec   Soil & Tillage Research  1986      Croatia
#
#                      Location  Latitude  Longitude  \
# 0              Montana, Froid     48.28    -105.10
# 1              Montana, Froid     48.28    -105.10
# 2              Montana, Froid     48.28    -105.10
# 3     Bossier City, Louisiana     32.42     -93.64
# 4     Bossier City, Louisiana     32.42     -93.64
# ...                       ...       ...        ...
# 4398                Fericanci     45.53      17.98
# 4399                Fericanci     45.53      17.98
# 4400                   Osijek     45.55      18.69
# 4401                   Osijek     45.55      18.69
# 4402                   Osijek     45.55      18.69
#
#      Soil information recorded in the paper pH (surface layer)  \
# 0                                sandy loam
# 1                                sandy loam
# 2                                sandy loam
# 3                                sandy loam                6.6
# 4                                sandy loam                6.6
# ...                                     ...                ...
# 4398                              available                4.8
# 4399                              available                4.8
# 4400                              available         5.3 to 6.4
# 4401                              available         5.3 to 6.4
# 4402                              available         5.3 to 6.4
#
#      Replications in experiment  ... Outlier of NT  Sowing month  \
# 0                             3  ...           NaN             9
# 1                             3  ...           NaN             9
# 2                             3  ...           NaN             9
# 3                             3  ...           NaN             6
# 4                             3  ...           NaN             6
# ...                         ...  ...           ...           ...
# 4398                          4  ...           NaN             4
# 4399                          4  ...           NaN             4
# 4400                          4  ...           NaN             4
# 4401                          4  ...           NaN             4
# 4402                          4  ...           NaN             4
#
#       Harvesting month           P           E       PB      Tave       Tmax  \
# 0                    8  395.800000  534.828000 -139.028   5.03333  24.798600
# 1                    8  260.300000  590.273000 -329.973   5.79167  29.191860
# 2                    8  397.300000  555.260000 -157.960   6.86667  29.487280
# 3                   10  511.900005  546.686888  -34.787  26.16000  35.331630
# 4                   10  475.099997  511.402611  -36.303  24.96000  34.272689
# ...                ...         ...         ...      ...       ...        ...
# 4398                10  584.800000  437.793000  147.007  15.00000  26.143220
# 4399                10  524.000000  484.803000   39.197  16.25714  26.767580
# 4400                10  533.100000  443.249000   89.851  15.75714  26.233920
# 4401                10  507.200000  488.113000   19.087  17.00000  27.076650
# 4402                10  374.500000  483.660000 -109.160  17.30000  26.919080
#
#            Tmin    ST
# 0    -20.095680  Loam
# 1    -21.602860  Loam
# 2    -16.195720  Loam
# 3     14.984884  Loam
# 4     13.003511  Loam
# ...         ...   ...
# 4398   3.250900  Loam
# 4399   4.045250  Loam
# 4400   3.628730  Loam
# 4401   4.489370  Loam
# 4402   3.412560  Loam
#
# [4403 rows x 53 columns]

# %%
display(df["Crop"].unique())
# Out:
# array(['wheat.winter', 'soybean', 'rice', 'maize', 'barley.winter',
#        'sorghum', 'barley.spring', 'wheat.spring', 'cotton', 'sunflower'],
#       dtype=object)

# %%
import numpy as np
import statsmodels.api as sm

# Data
X = np.random.rand(100, 2)  # Variabel independen (2 fitur)
y = np.random.rand(100)      # Variabel dependen

# Menambahkan kolom konstan untuk intercept
X = sm.add_constant(X)

# Membuat model regresi linear
model = sm.OLS(y, X).fit()

# Melakukan ANOVA
anova_results = sm.stats.anova_lm(model)

# Output hasil
print(anova_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      12 model = sm.OLS(y, X).fit()
#      14 # Melakukan ANOVA
# ---> 15 anova_results = sm.stats.anova_lm(model)
#      17 # Output hasil
#      18 print(anova_results)
#
# File ~/Desktop/learningML/.env/lib/python3.11/site-packages/statsmodels/stats/anova.py:353, in anova_lm(*args, **kwargs)
#     351 if len(args) == 1:
#     352     model = args[0]
# --> 353     return anova_single(model, **kwargs)
#     355 if typ not in [1, "I"]:
#     356     raise ValueError("Multiple models only supported for type I. "
#     357                      "Got type %s" % str(typ))
#
# File ~/Desktop/learningML/.env/lib/python3.11/site-packages/statsmodels/stats/anova.py:70, in anova_single(model, **kwargs)
#      67 nobs = exog.shape[0]
#      69 response_name = model.model.endog_names
# ---> 70 design_info = model.model.data.design_info
#      71 exog_names = model.model.exog_names
#      72 # +1 for resids
#
# AttributeError: 'ModelData' object has no attribute 'design_info'
