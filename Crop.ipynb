# %%
import pandas as pd
# Out:
# /var/folders/1q/ttq7y9792hl1j72br9_w4vzw0000gn/T/ipykernel_78734/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("./dataset/GRooTFullVersion.csv", encoding='latin1')
# Out:
# /var/folders/1q/ttq7y9792hl1j72br9_w4vzw0000gn/T/ipykernel_78734/33399234.py:1: DtypeWarning: Columns (6,7,8,11,15,23,25,30,31,37,41,51,62,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./dataset/GRooTFullVersion.csv", encoding='latin1')

# %%
display(df)
# Out:
#         GRooTID  source  versionSource  originalID referencesAbbreviated  \
# 0             1    FRED            2.0     33116.0         Aaltonen 1920
# 1             2    FRED            2.0     33115.0         Aaltonen 1920
# 2             3    FRED            2.0     33113.0         Aaltonen 1920
# 3             4    FRED            2.0     33112.0         Aaltonen 1920
# 4             5    FRED            2.0     33114.0         Aaltonen 1920
# ...         ...     ...            ...         ...                   ...
# 114217    50979  Roumet            NaN         NaN    Roumet_unpublished
# 114218    50979  Roumet            NaN         NaN    Roumet_unpublished
# 114219    50979  Roumet            NaN         NaN    Roumet_unpublished
# 114220    50979  Roumet            NaN         NaN    Roumet_unpublished
# 114221    50979  Roumet            NaN         NaN    Roumet_unpublished
#
#                                                references  \
# ...

# %%
display(df["genusTNRS"].unique())
# Out:
# array(['Betula', 'Picea', 'Pinus', ..., 'Prospero', 'Rhaponticum',
#        'Serapias'], dtype=object)

# %%
import numpy as np
import statsmodels.api as sm

# Data
X = np.random.rand(100, 2)  # Variabel independen (2 fitur)
y = np.random.rand(100)      # Variabel dependen

# Menambahkan kolom konstan untuk intercept
X = sm.add_constant(X)

# Membuat model regresi linear
model = sm.OLS(y, X).fit()

# Melakukan ANOVA
anova_results = sm.stats.anova_lm(model)

# Output hasil
print(anova_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      12 model = sm.OLS(y, X).fit()
#      14 # Melakukan ANOVA
# ---> 15 anova_results = sm.stats.anova_lm(model)
#      17 # Output hasil
#      18 print(anova_results)
#
# File ~/Desktop/learningML/.env/lib/python3.11/site-packages/statsmodels/stats/anova.py:353, in anova_lm(*args, **kwargs)
#     351 if len(args) == 1:
#     352     model = args[0]
# --> 353     return anova_single(model, **kwargs)
#     355 if typ not in [1, "I"]:
#     356     raise ValueError("Multiple models only supported for type I. "
#     357                      "Got type %s" % str(typ))
#
# File ~/Desktop/learningML/.env/lib/python3.11/site-packages/statsmodels/stats/anova.py:70, in anova_single(model, **kwargs)
#      67 nobs = exog.shape[0]
#      69 response_name = model.model.endog_names
# ...

# %%
my_list = ['a', 'b', 'c', 'd']

for index, value in enumerate(my_list, start=1):
    print(f'Index: {index}, Value: {value}')
# Out:
# Index: 1, Value: a
# Index: 2, Value: b
# Index: 3, Value: c
# Index: 4, Value: d
